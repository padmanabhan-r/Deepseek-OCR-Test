# %%
import os
import warnings

# Suppress tqdm warnings
os.environ["TQDM_DISABLE"] = "1"
warnings.filterwarnings("ignore", message=".*model of type.*")

import torch
from transformers import AutoModel, AutoTokenizer

# Prefer MPS; allow silent fallback for ops not supported on Metal
os.environ.setdefault("PYTORCH_ENABLE_MPS_FALLBACK", "1")

device = "mps" if torch.backends.mps.is_available() else "cpu"
dtype = torch.float16 if device == "mps" else torch.float32

MODEL_DIR = "/Users/paddy/Documents/Github/Deepseek-OCR-Test/DeepSeek-OCR"

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, trust_remote_code=True)

model = AutoModel.from_pretrained(
    MODEL_DIR,
    trust_remote_code=True,
    use_safetensors=True,
    _attn_implementation="eager",
).to(device=device, dtype=dtype).eval()
# Out:
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Some weights of DeepseekOCRForCausalLM were not initialized from the model checkpoint at /Users/paddy/Documents/Github/Deepseek-OCR-Test/DeepSeek-OCR and are newly initialized: ['model.vision_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import os
import warnings

os.environ["TQDM_DISABLE"] = "1"
warnings.filterwarnings("ignore")

import torch
from transformers import AutoModel, AutoTokenizer

os.environ.setdefault("PYTORCH_ENABLE_MPS_FALLBACK", "1")

device = "mps" if torch.backends.mps.is_available() else "cpu"
dtype = torch.float16 if device == "mps" else torch.float32

# Load directly from Hugging Face Hub
MODEL_NAME = "deepseek-ai/DeepSeek-OCR"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)

model = AutoModel.from_pretrained(
    MODEL_NAME,
    trust_remote_code=True,
    attn_implementation="eager",
).to(device=device, dtype=dtype).eval()
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: d41c5539-7400-4d68-bbef-6ba797e6e3bc)')' thrown while requesting HEAD https://huggingface.co/deepseek-ai/DeepSeek-OCR/resolve/main/tokenizer_config.json
# Retrying in 1s [Retry 1/5].
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# ...
# model-00001-of-000001.safetensors:   0%|          | 0.00/6.67G [00:00<?, ?B/s]
#   2025-10-23T15:26:30.451279Z ERROR  Python exception updating progress:, error: PyErr { type: <class 'LookupError'>, value: LookupError(<ContextVar name='shell_parent' at 0x10981ba10>), traceback: Some(<traceback object at 0x12df19c00>) }, caller: "src/progress_update.rs:313"
#     at /Users/runner/work/xet-core/xet-core/error_printer/src/lib.rs:28
#
# ...
